# %% [markdown]
# # Extracting text from image using OCR

# %%
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2build2).
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2build2).
# 0 upgraded, 0 newly installed, 0 to remove and 5 not upgraded.

# %%
# !tesseract
# Out:
# Usage:
#   tesseract --help | --help-extra | --version
#   tesseract --list-langs
#   tesseract imagename outputbase [options...] [configfile...]
#
# OCR options:
#   -l LANG[+LANG]        Specify language(s) used for OCR.
# NOTE: These options must occur before any configfile.
#
# Single options:
#   --help                Show this help message.
#   --help-extra          Show extra help for advanced users.
#   --version             Show version information.
#   --list-langs          List available languages for tesseract engine.

# %%
# %pip install pytesseract==0.3.10 pillow==10.3.0 tk==0.1.0 opencv-python==4.10.0.82
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip list
# Out:
# Package                    Version        Editable project location
# -------------------------- -------------- -----------------------------------------
# absl-py                    2.1.0
# aiohttp                    3.9.5
# aiosignal                  1.3.1
# annotated-types            0.7.0
# anyio                      4.4.0
# argon2-cffi                23.1.0
# argon2-cffi-bindings       21.2.0
# arrow                      1.3.0
# asprise-ocr-sdk-python-api 15.3.0.8
# asttokens                  2.4.1
# async-lru                  2.0.4
# async-timeout              4.0.3
# attrs                      23.2.0
# awscli                     1.33.4
# awscrt                     0.20.9
# Babel                      2.15.0
# backoff                    2.2.1
# beautifulsoup4             4.12.3
# bleach                     6.1.0
# boto3                      1.34.117
# botocore                   1.34.122
# cachetools                 5.3.3
# certifi                    2024.6.2
# ...

# %%
import errno
import cv2
import pytesseract
import numpy as np
import tkinter as tk
import os
import shutil
import re

from PIL import Image, ImageTk

fig_folder = 'crackathon/reports/figures'
tmp_folder = f'{fig_folder}/tmp'
img = cv2.imread(f'{fig_folder}/printed-prescription.png')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

config = "-l eng+jpn+kor+rus+chi_sim+vie+thai"

text = pytesseract.image_to_string(thresh, config=config)

print(text)
# Out:
# Dr. Akshara “<b ‘SMS hospital
#
# M. 5/503, Business Center, MG Road, Pune
#
# Reg. No: MMC 2018 - 411000.
# Ph; 5465647658, Timing: 09:00 AM -
# 01:00 PM, 06:00 PM - 08:00 PM |
# Closed: Sunday
#
#
#
#
#
# Date: 30-Aug-2023
# ID: 11 - OPD6 PATIENT (M) / 13 Mob. No.: 9423380390
# Address: PUNE
#
# Weight (Kg): 80, Height (Cm): 200 (B.M.I. = 20.00), BP: 120/80 mmHg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chief Complaints Glinical Findings
# * FEVER WITH CHILLS (4 DAYS) * THESE ARE TEST FINDINGS FOR A TEST
# * HEADACHE (2 DAYS) PATIENT
# * ENTERING SAMPLE DIAGNOSIS AND SAMPLE
# PRESCRIPTION
# Diagnosis:
# * MALARIA
# A
# Medicine Name Dosage Duration
#
# 1) TAB. ABCIXIMAB 1 Morning 8 Days
#
# (Tot:8 Tab)
# 2) TAB. VOMILAST 1 Morning, 1 Night 8 Days
#
# (After Food) (Tat: 16 Tab)
#
# DOXYLAMINE 1046 + PYRIDOXINE 10 MG +
# FOUC ACID 2.5 NG
# 3) CAP. ZOCLAR 500 1 Morning 3 Days
#
# (Tat:3 Cap)
# CLARITHROMYCIN 1P SOOMG
# 4) TAB, GESTAKIND 10/SR 1 Night 4 Days
#
# (Tot:4 Tab)
#
# ...
